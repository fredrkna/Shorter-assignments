# %%
from os.path import dirname, join as pjoin
import scipy.io as sio
from scipy.io import wavfile
from matplotlib import pyplot as plt
import numpy as np
from scipy.fftpack import fft
import copy
from IPython.display import clear_output
from scipy import signal

# %%
data_dir = pjoin(dirname(sio.__file__), 'tests', 'data')
wav_fname = pjoin(data_dir, 'guitar.wav')

# %%
samplerate, data = sio.wavfile.read(wav_fname)
#print(f"number of channels = {data.shape[0]}")
length = data.shape[0] / samplerate
print(f"length = {length}s")
dt = 1/samplerate
# Out:
# length = 18.483083900226756s

# %%
# %matplotlib notebook
time = np.linspace(0., length, data.shape[0])
plt.figure(1)
plt.plot(time, data)
#plt.plot(time, data[:, 1], label="Right channel")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.title("Sound signal from guitar")
plt.show()

#Measured signal
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
startE2 = int(0.46/dt)
sluttE2 = int(1.67/dt)
tE2 = time[startE2:sluttE2]
dE2 = data[startE2:sluttE2]

NE2 = dE2.shape[0]
spE2 = np.fft.fftshift(fft(dE2))
freqE2 = np.fft.fftshift(np.fft.fftfreq(tE2.shape[-1], d=dt))

tall = np.array([1,2,3,4,5,6])
plt.figure()
plt.vlines(82.4*tall, 0, 500, "r")
plt.plot(freqE2, np.abs(spE2)/NE2) #, freq, sp.imag)
plt.xlim(0,500)
plt.title("FFT of guitar's E2 note'")
plt.xlabel("f [Hz]")
plt.ylabel("Amplitude")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Amplitude')

# %%
startE2 = int(1.8/dt)
sluttE2 = int(3.0/dt)
tE2 = time[startE2:sluttE2]
dE2 = data[startE2:sluttE2]

NE2 = dE2.shape[0]
spE2 = np.fft.fftshift(fft(dE2))
freqE2 = np.fft.fftshift(np.fft.fftfreq(tE2.shape[-1], d=dt))

tall = np.array([1,2,3,4,5,6])
plt.figure()
plt.vlines(110*tall, 0, 500, "r")
plt.plot(freqE2, np.abs(spE2)/NE2) #, freq, sp.imag)
plt.xlim(0,500)
plt.title("FFT of guitar's A2 note'")
plt.xlabel("f [Hz]")
plt.ylabel("Amplitude")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Amplitude')

# %%
startE2 = int(3.2/dt)
sluttE2 = int(4.4/dt)
tE2 = time[startE2:sluttE2]
dE2 = data[startE2:sluttE2]

NE2 = dE2.shape[0]
spE2 = np.fft.fftshift(fft(dE2))
freqE2 = np.fft.fftshift(np.fft.fftfreq(tE2.shape[-1], d=dt))

tall = np.array([1,2,3,4,5,6])
plt.figure()
plt.vlines(147*tall, 0, 500, "r")
plt.plot(freqE2, np.abs(spE2)/NE2) #, freq, sp.imag)
plt.xlim(0,500)
plt.title("FFT of guitar's D3 note'")
plt.xlabel("f [Hz]")
plt.ylabel("Amplitude")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Amplitude')

# %%
startE2 = int(4.56/dt)
sluttE2 = int(6.74/dt)
tE2 = time[startE2:sluttE2]
dE2 = data[startE2:sluttE2]

NE2 = dE2.shape[0]
spE2 = np.fft.fftshift(fft(dE2))
freqE2 = np.fft.fftshift(np.fft.fftfreq(tE2.shape[-1], d=dt))

tall = np.array([1,2,3,4,5,6])
plt.figure()
plt.vlines(196*tall, 0, 300, "r")
plt.plot(freqE2, np.abs(spE2)/NE2) #, freq, sp.imag)
plt.xlim(0,800)
plt.title("FFT of guitar's G3 note'")
plt.xlabel("f [Hz]")
plt.ylabel("Amplitude")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Amplitude')

# %%
startE2 = int(5.9/dt)
sluttE2 = int(7.2/dt)
tE2 = time[startE2:sluttE2]
dE2 = data[startE2:sluttE2]

NE2 = dE2.shape[0]
spE2 = np.fft.fftshift(fft(dE2))
freqE2 = np.fft.fftshift(np.fft.fftfreq(tE2.shape[-1], d=dt))

tall = np.array([1,2,3,4,5,6])
plt.figure()
plt.vlines(246*tall, 0, 300, "r")
plt.plot(freqE2, np.abs(spE2)/NE2) #, freq, sp.imag)
plt.xlim(0,800)
plt.title("FFT of guitar's B3 note'")
plt.xlabel("f [Hz]")
plt.ylabel("Amplitude")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Amplitude')

# %%
startE2 = int(7.3/dt)
sluttE2 = int(10.2/dt)
tE2 = time[startE2:sluttE2]
dE2 = data[startE2:sluttE2]

NE2 = dE2.shape[0]
spE2 = np.fft.fftshift(fft(dE2))
freqE2 = np.fft.fftshift(np.fft.fftfreq(tE2.shape[-1], d=dt))

tall = np.array([1,2,3,4,5,6])
plt.figure()
plt.vlines(330*tall, 0, 300, "r")
plt.plot(freqE2, np.abs(spE2)/NE2) #, freq, sp.imag)
plt.xlim(0,1000)
plt.title("FFT of guitar's E4 note'")
plt.xlabel("f [Hz]")
plt.ylabel("Amplitude")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Amplitude')

# %%
#All the guitar strings matched their frequencies and overtones. The guitar wasn't silenced after each string was plucked,
#so there is a bit more noice from the previous strings than necessary here.The right ones are those on top of red lines.

# %%
data_dir1 = pjoin(dirname(sio.__file__), 'tests', 'data')
wav_fname1 = pjoin(data_dir1, 'fysikk.wav')

# %%
samplerate1, data1 = sio.wavfile.read(wav_fname1)
#print(f"number of channels = {data.shape[0]}")
length1 = data1.shape[0] / samplerate1
print(f"length = {length1}s")
dt1 = 1/samplerate1
# Out:
# length = 60.0s

# %%
# %matplotlib notebook
time1 = np.linspace(0., length1, data1.shape[0])
plt.figure(5)
plt.plot(time1, data1)
#plt.plot(time, data[:, 1], label="Right channel")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
#plt.xlim(1.8,13.8)
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.title("Sound signal from car passing by")
plt.show()

Ns = 1/dt1
print(Ns)
#Measured signal
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 6000.0

# %%
tIN = time1[int(8/dt1):int(9/dt1)]
dIN = data1[int(8/dt1):int(9/dt1)]

plt.figure()
NIN = dIN.shape[0]
spIN = np.fft.fftshift(fft(dIN))
#freq = np.fft.fftshift(np.fft.fftfreq(time.shape[-1]))
freqIN = np.fft.fftshift(np.fft.fftfreq(NIN, d=dt1))
plt.plot(freqIN, np.abs(spIN/NIN)) #, freq, sp.imag)
plt.title("FFT of 1st car incoming")
plt.xlabel("f [Hz]")
plt.ylabel("Amplitude")
plt.xlim(2300, 2800)
plt.ylim(0, 50)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (0, 50)

# %%
tUT = time1[int(11.5/dt1):int(12.5/dt1)]
dUT = data1[int(11.5/dt1):int(12.5/dt1)]
# %matplotlib notebook
NUT = dUT.shape[0]
spUT = np.fft.fftshift(fft(dUT))
#freq = np.fft.fftshift(np.fft.fftfreq(time.shape[-1]))
freqUT = np.fft.fftshift(np.fft.fftfreq(NUT, d=dt1))
plt.figure()
plt.plot(freqUT, np.abs(spUT/NUT)) #, freqUT, spUT.imag/NUT)
plt.title("FFT of 1st car outgoing")
plt.xlabel("f [Hz]")
plt.ylabel("Amplitude")
plt.xlim(2300, 2800)
plt.show()
plt.ylim(0, 50)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (0, 50)

# %%
tIN = time1[int(22/dt1):int(22.5/dt1)]
dIN = data1[int(22/dt1):int(22.5/dt1)]

# %matplotlib notebook

plt.figure()
NIN = dIN.shape[0]
spIN = np.fft.fftshift(fft(dIN))
#freq = np.fft.fftshift(np.fft.fftfreq(time.shape[-1]))
freqIN = np.fft.fftshift(np.fft.fftfreq(NIN, d=dt1))
plt.plot(freqIN, np.abs(spIN/NIN)) #, freq, sp.imag)
plt.title("FFT of 2nd car incoming")
plt.xlabel("f [Hz]")
plt.ylabel("Amplitude")
plt.xlim(2300, 2800)
plt.ylim(0, 50)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (0, 50)

# %%
tUT = time1[int(24.85/dt1):int(25.35/dt1)]
dUT = data1[int(24.85/dt1):int(25.35/dt1)]
# %matplotlib notebook
NUT = dUT.shape[0]
spUT = np.fft.fftshift(fft(dUT))
#freq = np.fft.fftshift(np.fft.fftfreq(time.shape[-1]))
freqUT = np.fft.fftshift(np.fft.fftfreq(NUT, d=dt1))
plt.figure()
plt.plot(freqUT, np.abs(spUT/NUT)) #, freqUT, spUT.imag/NUT)
plt.plot(2296, 16, "ro")
plt.title("FFT of 2nd car outgoing")
plt.xlabel("f [Hz]")
plt.ylabel("Amplitude")
plt.xlim(2200, 2800)
plt.show()
plt.ylim(0, 50)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (0, 50)

# %%
# %matplotlib inline
l = 0.05
s = 18

a2 = 2
X = int(9/l)
T = np.zeros(X)
F = np.zeros(X)
#temp = 1533
P = np.zeros(X)
for i in range(X):
    timeINT = time1[int((s+l*i)/dt1):int((s+0.5+l*i)/dt1)]
    dataINT = data1[int((s+l*i)/dt1):int((s+0.5+l*i)/dt1)]
    NINT = dataINT.shape[0]
    spINT = np.fft.fftshift(fft(dataINT))
    freqINT = np.fft.fftshift(np.fft.fftfreq(NINT, d=dt1))
    plt.xlim(2000, 2800)
    plt.ylim(0, 100)
    plt.plot(freqINT, np.abs(spINT/NINT))
    plt.title(f"t = {s + l*i} of {X*l+s}")
    plt.show()
    clear_output(wait=True)

# %%
v2 = 3.6*(2752-2296)*340/(2752+2296)

v1 = 3.6*(2692-2413)*340/(2692+2413)

print(3.6*340*(2692 - 2413)/(2692 + 2413))

print("Første gangen kjører bilen i", v1, "km i timen, andre gangen", v2, "km i timen.")
# Out:
# 66.89441723800196
# Første gangen kjører bilen i 66.89441723800196 km i timen, andre gangen 110.56735340729001 km i timen.
